# %% [markdown]
# <a href="https://colab.research.google.com/github/20NN1A05F1/OIBSIP/blob/main/Regularization_on_Multiclass_classification_using_Reuters_Newswire_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
#Each review (row) is of different size. This data needs to be made uniform.
# i.e. each reviuew (i.e. row) needs to be onehotencoded to a length of 10,000 (we have decided to have only 10000 features)
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
#create the layers
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 4s 120ms/step - loss: 7.0974 - categorical_accuracy: 0.4558 - val_loss: 3.6257 - val_categorical_accuracy: 0.5663
# Epoch 2/25
# 16/16 [==============================] - 1s 56ms/step - loss: 3.3093 - categorical_accuracy: 0.5706 - val_loss: 3.0314 - val_categorical_accuracy: 0.5863
# Epoch 3/25
# 16/16 [==============================] - 1s 60ms/step - loss: 2.9737 - categorical_accuracy: 0.6139 - val_loss: 2.8262 - val_categorical_accuracy: 0.6562
# Epoch 4/25
# 16/16 [==============================] - 1s 94ms/step - loss: 2.7920 - categorical_accuracy: 0.6412 - val_loss: 2.6629 - val_categorical_accuracy: 0.6700
# Epoch 5/25
# 16/16 [==============================] - 1s 84ms/step - loss: 2.6510 - categorical_accuracy: 0.6617 - val_loss: 2.5537 - val_categorical_accuracy: 0.6562
# Epoch 6/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.5367 - categorical_accuracy: 0.6737 - val_loss: 2.4406 - val_categorical_accuracy: 0.6800
# Epoch 7/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.4441 - categorical_accuracy: 0.6794 - val_loss: 2.3624 - val_categorical_accuracy: 0.6837
# Epoch 8/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.3611 - categorical_accuracy: 0.6868 - val_loss: 2.3166 - val_categorical_accuracy: 0.6800
# Epoch 9/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.2995 - categorical_accuracy: 0.6870 - val_loss: 2.2403 - val_categorical_accuracy: 0.6913
# Epoch 10/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.2368 - categorical_accuracy: 0.6927 - val_loss: 2.2167 - val_categorical_accuracy: 0.6888
# Epoch 11/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.1916 - categorical_accuracy: 0.6925 - val_loss: 2.1535 - val_categorical_accuracy: 0.6950
# Epoch 12/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.1546 - categorical_accuracy: 0.6935 - val_loss: 2.1096 - val_categorical_accuracy: 0.6963
# Epoch 13/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.1136 - categorical_accuracy: 0.6967 - val_loss: 2.1190 - val_categorical_accuracy: 0.6975
# Epoch 14/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.0873 - categorical_accuracy: 0.6958 - val_loss: 2.0558 - val_categorical_accuracy: 0.6988
# Epoch 15/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.0627 - categorical_accuracy: 0.6968 - val_loss: 2.0315 - val_categorical_accuracy: 0.6950
# Epoch 16/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.0352 - categorical_accuracy: 0.6985 - val_loss: 2.0243 - val_categorical_accuracy: 0.6963
# Epoch 17/25
# 16/16 [==============================] - 1s 69ms/step - loss: 2.0190 - categorical_accuracy: 0.6995 - val_loss: 1.9949 - val_categorical_accuracy: 0.6963
# Epoch 18/25
# 16/16 [==============================] - 1s 93ms/step - loss: 1.9982 - categorical_accuracy: 0.6996 - val_loss: 1.9998 - val_categorical_accuracy: 0.6925
# Epoch 19/25
# 16/16 [==============================] - 1s 81ms/step - loss: 1.9834 - categorical_accuracy: 0.7006 - val_loss: 1.9701 - val_categorical_accuracy: 0.6925
# Epoch 20/25
# 16/16 [==============================] - 1s 54ms/step - loss: 1.9682 - categorical_accuracy: 0.6990 - val_loss: 1.9469 - val_categorical_accuracy: 0.7025
# Epoch 21/25
# 16/16 [==============================] - 1s 87ms/step - loss: 1.9514 - categorical_accuracy: 0.7006 - val_loss: 1.9501 - val_categorical_accuracy: 0.7000
# Epoch 22/25
# 16/16 [==============================] - 1s 94ms/step - loss: 1.9364 - categorical_accuracy: 0.7015 - val_loss: 1.9186 - val_categorical_accuracy: 0.6950
# Epoch 23/25
# 16/16 [==============================] - 1s 63ms/step - loss: 1.9191 - categorical_accuracy: 0.7044 - val_loss: 1.9213 - val_categorical_accuracy: 0.6975
# Epoch 24/25
# 16/16 [==============================] - 1s 51ms/step - loss: 1.9075 - categorical_accuracy: 0.7058 - val_loss: 1.9019 - val_categorical_accuracy: 0.6963
# Epoch 25/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.8930 - categorical_accuracy: 0.7046 - val_loss: 1.8883 - val_categorical_accuracy: 0.7075

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
